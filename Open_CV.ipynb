# %% [markdown]
# <a href="https://colab.research.google.com/github/gbroy1999/deep-learning/blob/master/Open_CV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c9a8e8f9-b666-4eac-90b3-d495c0b95336" name="files[]" multiple disabled />
#      <output id="result-c9a8e8f9-b666-4eac-90b3-d495c0b95336">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 3.jpg to 3.jpg

# %%
import matplotlib.pyplot as plt
ax = plt.subplots(figsize=(10,10))

# %%
img = cv2.imread("3.jpg",0)#GrayScale
img1 = cv2.imread("3.jpg",1)#Colour image
img2 = cv2.imread("3.jpg",-1)#Transparent



print(type(img1))
print(img1)
print(img1.shape)
print(img1.ndim)
# Out:
# <class 'numpy.ndarray'>
# [[[189 104  54]
#   [189 104  54]
#   [189 104  54]
#   ...
#   [172  88  40]
#   [172  88  40]
#   [172  88  40]]
#
#  [[189 104  54]
#   [189 104  54]
#   [189 104  54]
#   ...
#   [172  88  40]
#   [172  88  40]
#   [172  88  40]]
#
#  [[189 104  54]
#   [189 104  54]
#   [189 104  54]
#   ...
#   [172  88  40]
#   [172  88  40]
#   [172  88  40]]
#
#  ...
#
#  [[179  95  47]
#   [179  95  47]
#   [178  94  46]
#   ...
#   [168  83  38]
#   [168  83  38]
#   [167  82  37]]
#
#  [[179  95  47]
#   [179  95  47]
#   [178  94  46]
#   ...
#   [168  83  38]
#   [168  83  38]
#   [167  82  37]]
#
#  [[179  95  47]
#   [179  95  47]
#   [178  94  46]
#   ...
#   [168  83  38]
#   [168  83  38]
#   [167  82  37]]]
# (187, 269, 3)
# 3

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(img1)
#cv2.waitKey(0)
cv2_waitKey(5000)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=269x187 at 0x7F758728E550>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-a4160d45a82c> in <module>()
#       2 cv2_imshow(img1)
#       3 #cv2.waitKey(0)
# ----> 4 cv2_waitKey(5000)
#       5 cv2.destroyAllWindows()
#
# NameError: name 'cv2_waitKey' is not defined

# %%
 from google.colab.patches import cv2_imshow
resized_img = cv2.resize(img,(100,100))
cv2_imshow(resized_img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=L size=100x100 at 0x7F758729B748>

# %%
print (type(img.shape))
#resized_img = cv2.resize(img,img.shape[1]/2,img.shape[0]/2)
#cv2.imshow("Window_name",resized_img)
#cv2.waitKey(0)
#cv2.destroyAllWindows()
# Out:
# <class 'tuple'>

# %%
resized_img = cv2.resize(img,(int(img.shape[1]/3),int(img.shape[0]/3)))
cv2.imshow(resized_img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# DisabledFunctionError                     Traceback (most recent call last)
# <ipython-input-26-19c8289741e8> in <module>()
#       1 resized_img = cv2.resize(img,(int(img.shape[1]/3),int(img.shape[0]/3)))
# ----> 2 cv2.imshow(resized_img)
#       3 cv2.waitKey(0)
#       4 cv2.destroyAllWindows()
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_import_hooks/_cv2.py in wrapped(*args, **kwargs)
#      50   def wrapped(*args, **kwargs):
#      51     if not os.environ.get(env_var, False):
# ---> 52       raise DisabledFunctionError(message, name or func.__name__)
#      53     return func(*args, **kwargs)
#      54
#
# DisabledFunctionError: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow

# %%
resized_img = cv2.resize(img,(int(img.shape[1]/3),int(img.shape[0]/3)))
cv2.imshow(resized_img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# DisabledFunctionError                     Traceback (most recent call last)
# <ipython-input-26-19c8289741e8> in <module>()
#       1 resized_img = cv2.resize(img,(int(img.shape[1]/3),int(img.shape[0]/3)))
# ----> 2 cv2.imshow(resized_img)
#       3 cv2.waitKey(0)
#       4 cv2.destroyAllWindows()
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_import_hooks/_cv2.py in wrapped(*args, **kwargs)
#      50   def wrapped(*args, **kwargs):
#      51     if not os.environ.get(env_var, False):
# ---> 52       raise DisabledFunctionError(message, name or func.__name__)
#      53     return func(*args, **kwargs)
#      54
#
# DisabledFunctionError: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow

# %%
from google.colab.patches import cv2_imshow
resized_img = cv2.resize(img,(int(img.shape[1]/3),int(img.shape[0]/3)))
cv2_imshow(resized_img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=L size=89x62 at 0x7F758729B320>

# %%
import cv2
import glob
#from google.colab.patches import cv2_imshow
images=glob.glob("*.jpg")
for image in images:
   img=cv2.imread(image,0)
   re=cv2.resize(img,(100,100))
   cv2_imshow(re)
   cv2.waitKey(500)
   cv2.destroyAllWindows()
   cv2.imwrite("resizd_"+image,re)
# Out:
# <PIL.Image.Image image mode=L size=100x100 at 0x7F75872B2898>
# <PIL.Image.Image image mode=L size=100x100 at 0x7F75872B22E8>
# <PIL.Image.Image image mode=L size=100x100 at 0x7F75872B2898>
# <PIL.Image.Image image mode=L size=100x100 at 0x7F75872B22E8>

# %%
import cv2
​
face_cascade = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")
​
img = cv2.imread("profile picture.jpg")

​
gray_img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
# Out:
#   File "<ipython-input-66-9ee00016b6fd>", line 2
#     ​
#     ^
# SyntaxError: invalid character in identifier

# %%
import cv2
from google.colab.patches import cv2_imshow
faces = face_cascade.detectMultiScale(gray_img,scaleFactor = 1.05,minNeighbors = 5)
print (type(faces))
print(faces)
cv2_imshow(gray_img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-69ae0b0d8190> in <module>()
#       1 import cv2
#       2 from google.colab.patches import cv2_imshow
# ----> 3 faces = face_cascade.detectMultiScale(gray_img,scaleFactor = 1.05,minNeighbors = 5)
#       4 print (type(faces))
#       5 print(faces)
#
# NameError: name 'face_cascade' is not defined
